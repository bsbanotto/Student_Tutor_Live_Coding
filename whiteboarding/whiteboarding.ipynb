# %%
#imports
from collections import Counter
import random
import time
import matplotlib.pyplot as plt

# %%
# Make arrays
# arr_1e1 = [random.randint(0, 10) for x in range(0, 10)]
# arr_1e2 = [random.randint(0, 10) for x in range(0, 100)]
# arr_1e3 = [random.randint(0, 10) for x in range(0, 1000)]
arr_1e4 = [random.randint(0, 10) for x in range(0, 10000)]
arr_1e5 = [random.randint(0, 10) for x in range(0, 100000)]
arr_1e6 = [random.randint(0, 10) for x in range(0, 1000000)]
arr_1e7 = [random.randint(0, 10) for x in range(0, 10000000)]
arr_1e8 = [random.randint(0, 10) for x in range(0, 100000000)]

# %%
k = 4

# %%
# # arr_1e1
# start_10 = time.time()
# return_list = [sorted(Counter(arr_1e1).items(), key=lambda x: x[1], reverse=True)[i][0] for i in range(0, k)]
# end_10 = time.time()
# time_10 = end_10 - start_10

# %%
# # arr_1e2
# start_100 = time.time()
# return_list = [sorted(Counter(arr_1e2).items(), key=lambda x: x[1], reverse=True)[i][0] for i in range(0, k)]
# end_100 = time.time()
# time_100 = end_100 - start_100

# %%
# # arr_1e3
# start_1000 = time.time()
# return_list = [sorted(Counter(arr_1e3).items(), key=lambda x: x[1], reverse=True)[i][0] for i in range(0, k)]
# end_1000 = time.time()
# time_1000 = end_1000 - start_1000

# %%
# arr_1e4
start_10000 = time.time()
return_list = [sorted(Counter(arr_1e4).items(), key=lambda x: x[1], reverse=True)[i][0] for i in range(0, k)]
end_10000 = time.time()
time_10000 = end_10000 - start_10000

# %%
# arr_1e5
start_100000 = time.time()
return_list = [sorted(Counter(arr_1e5).items(), key=lambda x: x[1], reverse=True)[i][0] for i in range(0, k)]
end_100000 = time.time()
time_100000 = end_100000 - start_100000

# %%
# arr_1e6
start_1000000 = time.time()
return_list = [sorted(Counter(arr_1e6).items(), key=lambda x: x[1], reverse=True)[i][0] for i in range(0, k)]
end_1000000 = time.time()
time_1000000 = end_1000000 - start_1000000

# %%
# arr_1e7
start_10000000 = time.time()
return_list = [sorted(Counter(arr_1e7).items(), key=lambda x: x[1], reverse=True)[i][0] for i in range(0, k)]
end_10000000 = time.time()
time_10000000 = end_10000000 - start_10000000

# %%
# arr_1e8
start_100000000 = time.time()
return_list = [sorted(Counter(arr_1e8).items(), key=lambda x: x[1], reverse=True)[i][0] for i in range(0, k)]
end_100000000 = time.time()
time_100000000 = end_100000000 - start_100000000

# %%
# arr_1e9
# start_1000000000 = time.time()
# return_list = [sorted(Counter(arr_1e9).items(), key=lambda x: x[1], reverse=True)[i][0] for i in range(0, k)]
# end_1000000000 = time.time()
# time_1000000000 = end_1000000000 - start_1000000000

# %%
x = [10000, 100000, 1000000, 10000000, 100000000]
y = [time_10000, time_100000, time_1000000, time_10000000, time_100000000]

# %%
plt.loglog(x, y)
plt.xlabel("Length of Array")
plt.ylabel("Time to Calculate (s)")
plt.title("Time Complexity Top k Frequent Elements")
plt.show()
